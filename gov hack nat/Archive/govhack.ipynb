# %%
# open .shp file
import geopandas as gpd
import folium

gdf = gpd.read_file('EXTRACT_POLYGON.shp')

gdf = gdf.to_crs(epsg=4326)

print(gdf.head())
# Out:
#   d_y_n_ID                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            
# ...

# %%
# Convert the GeoDataFrame to GeoJSON
geojson_data = gdf.to_json()

# Create a folium map centered around the mean coordinates of the geometries
center = [gdf.geometry.centroid.y.mean(), gdf.geometry.centroid.x.mean()]
m = folium.Map(location=center, zoom_start=12)

# Add the GeoJSON layer to the map
folium.GeoJson(data=geojson_data, name="geojson").add_to(m)

# Add layer control to the map
folium.LayerControl().add_to(m)

# Display the map
m
# Out:
# C:\Users\Natas\AppData\Local\Temp\ipykernel_8256\146898574.py:5: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   center = [gdf.geometry.centroid.y.mean(), gdf.geometry.centroid.x.mean()]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
# ...

# %%
import pandas as pd

# Read the Excel file
df = pd.read_excel('Tables from Rent Report - March quarter 2024.xlsx', sheet_name = 'Table 6')



# Display the dataframe
df
# Out:
#    Table 6: New lettings for statistical regions           Unnamed: 1
# 0                                         Region  2024-03-01 00:00:00  \
# 1                         Metropolitan Melbourne                  NaN
# 2                                Inner Melbourne                13337
# 3                        Inner Eastern Melbourne                 5508
# 4                             Southern Melbourne                 3565
# 5                              Western Melbourne                 6972
# 6                        North Western Melbourne                 3886
# 7                        North Eastern Melbourne                 3558
# 8                        Outer Eastern Melbourne                 1588
# 9                        South Eastern Melbourne                 3355
# 10                          Mornington Peninsula                 1518
# 11                             Regional Victoria                  NaN
# ...
