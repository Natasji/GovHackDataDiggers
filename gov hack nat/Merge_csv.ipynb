# %%
#Mount to google colab

from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/Colab Notebooks/GovHackTrafficDeakin/gov hack nat

# %% [markdown]
# Some functions (round coordinates)

# %%
import pandas as pd
# Function to round LATITUDE and LONGITUDE to n decimal places, same as other dfs
def round_lat_lon(df, places=5):
    df['LATITUDE'] = df['LATITUDE'].round(places)
    df['LONGITUDE'] = df['LONGITUDE'].round(places)

# %% [markdown]
# # Use accident.csv as base

# %%
df = pd.read_csv('ACCIDENT.csv')

# Extract neccessay columns
df = df[['ACCIDENT_NO', 'NODE_ID', 'ACCIDENT_DATE', 'ACCIDENT_TIME', 'ACCIDENT_TYPE', 'DAY_OF_WEEK', 'SEVERITY', 'ROAD_GEOMETRY', 'SPEED_ZONE']]

df
# Out:
#          ACCIDENT_NO  NODE_ID ACCIDENT_DATE ACCIDENT_TIME  ACCIDENT_TYPE
# 0       T20120000012    41780    2012-01-01      02:00:00              1  \
# 1       T20120000013    69811    2012-01-01      03:35:00              1
# 2       T20120000018    22636    2012-01-01      05:15:00              4
# 3       T20120000021   248597    2012-01-01      07:30:00              4
# 4       T20120000028   248598    2012-01-01      04:00:00              4
# ...              ...      ...           ...           ...            ...
# 171094  T20240000234   795204    2023-12-31      14:10:00              1
# 171095  T20240000022   797077    2023-12-31      21:35:00              4
# 171096  T20240000017    50791    2023-12-31      14:00:00              1
# 171097  T20230030999   795243    2023-12-31      15:33:00              2
# 171098  T20240000006   795125    2023-12-31      20:02:00              1
#
#         DAY_OF_WEEK  SEVERITY  ROAD_GEOMETRY  SPEED_ZONE
# ...

# %%
dataset = {
    'accident location': {'file': 'ACCIDENT_LOCATION.csv', 'columns': ['ACCIDENT_NO', 'NODE_ID', 'ROAD_TYPE', 'ROAD_TYPE_INT'], 'id': ['ACCIDENT_NO', 'NODE_ID']},
    'atmospheric': {'file': 'ATMOSPHERIC_COND.csv', 'columns': ['ACCIDENT_NO', 'ATMOSPH_COND'], 'id': ['ACCIDENT_NO']},
    'node': {'file': 'NODE.csv', 'columns': ['ACCIDENT_NO', 'NODE_ID', 'LATITUDE', 'LONGITUDE', 'POSTCODE_CRASH'], 'id': ['ACCIDENT_NO', 'NODE_ID']},
    'person': {'file': 'PERSON.csv', 'columns': ['ACCIDENT_NO', 'AGE_GROUP'], 'id': ['ACCIDENT_NO']},
    'road surface': {'file': 'ROAD_SURFACE_COND.csv', 'columns': ['ACCIDENT_NO', 'SURFACE_COND'], 'id': ['ACCIDENT_NO']},
    'sub_dca': {'file': 'SUB_DCA.csv', 'columns': ['ACCIDENT_NO', 'SUB_DCA_CODE'], 'id': ['ACCIDENT_NO']},
    'speed sign': {'file': 'Speed_Signs_August_2024_csv.csv', 'columns': ['sign_size', 'latitude', 'longitude', 'speed', 'sign_type'], 'id': ['LATITUDE', 'LONGITUDE']},
    'traffic lights': {'file': 'Traffic_Lights_csv.csv', 'columns': ['latitude', 'longitude', 'SITE_TYPE' ], 'id': ['LATITUDE', 'LONGITUDE']}
}

# %% [markdown]
# # *test view data

# %%
test = "traffic lights"
temp_df = pd.read_csv(dataset[test]['file'])

# Extract neccessay columns
temp_df = temp_df[dataset[test]['columns']]

temp_df.columns = temp_df.columns.str.upper()
if 'LATITUDE' in temp_df.columns and 'LONGITUDE' in temp_df.columns:
    round_lat_lon(temp_df)

print(temp_df.head())
# Out:
#    LATITUDE  LONGITUDE SITE_TYPE
# 0 -38.23666  144.37788       INT
# 1 -37.86925  145.24197       POS
# 2 -36.76131  144.28034       INT
# 3 -38.19567  145.13371       INT
# 4 -37.78613  144.85338       POS

# %% [markdown]
# # Merge datasets

# %%
for file in dataset:
    temp_df = pd.read_csv(dataset[file]['file'])
    temp_df = temp_df[dataset[file]['columns']]
    temp_df.columns = temp_df.columns.str.upper()
    if 'LATITUDE' in temp_df.columns and 'LONGITUDE' in temp_df.columns:
        round_lat_lon(temp_df)
    df = pd.merge(df, temp_df, on=dataset[file]['id'], how='left')

# Display the updated node_df DataFrame
df
# Out:
# C:\Users\Natas\AppData\Local\Temp\ipykernel_6220\1006555816.py:2: DtypeWarning: Columns (30,31,35,37,38,40,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   temp_df = pd.read_csv(dataset[file]['file'])
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[54], line 7
#       5     if 'LATITUDE' in temp_df.columns and 'LONGITUDE' in temp_df.columns:
#       6         round_lat_lon(temp_df)
# ----> 7     df = pd.merge(df, temp_df, on=dataset[file]['id'], how='left')
#       9 # Display the updated node_df DataFrame
#      10 df
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\reshape\merge.py:158, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
# ...

# %%
df.to_csv('combined.csv', index=False)

# %% [markdown]
# 👇*if picking up from file

# %%
df = pd.read_csv('combined.csv')

# %%
missing_ratio = df.isnull().mean()
missing_ratio
# Out:
# ACCIDENT_NO       0.000000
# NODE_ID           0.000000
# ACCIDENT_DATE     0.000000
# ACCIDENT_TIME     0.000000
# ACCIDENT_TYPE     0.000000
# DAY_OF_WEEK       0.000000
# SEVERITY          0.000000
# ROAD_GEOMETRY     0.000000
# SPEED_ZONE        0.000000
# ROAD_TYPE         0.934948
# ROAD_TYPE_INT     0.934894
# ATMOSPH_COND      0.000000
# LATITUDE          0.933888
# LONGITUDE         0.933888
# POSTCODE_CRASH    0.933888
# AGE_GROUP         0.000000
# SURFACE_COND      0.000000
# SUB_DCA_CODE      0.000268
# SIGN_SIZE         0.103320
# SPEED             0.066112
# SIGN_TYPE         0.066112
# SITE_TYPE         1.000000
# dtype: float64
